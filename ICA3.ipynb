# %% [markdown]
# <a href="https://colab.research.google.com/github/2024ehsan/DSC-502/blob/main/ICA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/DATA/lego_setsHB.csv'

# %%
Price = {}
Difficulty = {}

# %%
os.listdir('/content/drive/My Drive/DATA')
# Out:
# ['lego_setsHB.csv']

# %%
with open(file_path, 'r', encoding='utf-8') as file:
    for i in range(1000):
        line = file.readline()
        if not line:
            break

        parts = line.strip().split(',')

        if len(parts) > 5:
            product_id = parts[0]
            price = parts[1]
            difficulty = parts[5]

            Price[product_id] = price
            Difficulty[product_id] = difficulty
